# %%
#task1 linear regression
import matplotlib.pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression
import math

# %%
#TODO read point from txt
file = open('case1.txt')

# %%
#parsing the file
x = []
y = []
for i in file:
    point = i.rstrip().split(',')
    x.append(float(point[0]))
    y.append(float(point[1]))

# %%
#plot the data
plt.scatter(x,y, s=1)
plt.show()

# %%
#change the x,y into numpy array
x = np.array(x).reshape((-1, 1))
y = np.array(y)
print(x)
print(y)
# Out:
# [[0.0000e+00]
#  [4.0000e-03]
#  [8.0000e-03]
#  ...
#  [2.5988e+01]
#  [2.5992e+01]
#  [2.5996e+01]]
# [269.08 278.5  292.   ... 103.88 147.67 125.38]

# %%
#creating a model
model = LinearRegression()
model.fit(x, y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False)

# %%
r_sq = model.score(x, y)
print('coefficient of determination:', r_sq)
# Out:
# coefficient of determination: 0.001067939802544382

# %%
#draw the line
y_hat = model.predict(x)
plt.scatter(x,y, s=1)
plt.plot(x,y_hat,color=(0,1,0))

# %%
#Calculate the confidence interval of error for 99.9% confidence level.
mean = np.mean(y) #mean
std = np.std(y) #standard deviation
st_error = std / math.sqrt(y.size) #standard error
# For 99.9% confidence level z= 3.291
z = 3.291
ME = z * st_error #Margin error
print("Mean value: ",mean)
print("confidence interval: ", mean+ME, " , ", mean-ME)
# Out:
# Mean value:  197.9183074
# confidence interval:  201.9890012786602  ,  193.8476135213398

# %%
#TODO exclude outlires in linear regression
